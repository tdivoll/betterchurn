# %% [markdown]
# # Create Hospital Metric / Patient Survey Data Frame

# %% [markdown]
# ### First we read our hospital survey data files into one dataframe and assign the filenames containing hospital IDs to a new column in the dataframe. Files were first downloaded from:
# http://www.healthcarereportcard.illinois.gov/

# %%
#combine data files for each hospital in the directory

import pandas as pd
import glob, os

files = glob.glob('/home/tjd/InsightFiles/IllinoisReportCards/hospital*') #grabs all files from the directory (n = 184)

#concatenate files but also add file name as a new column to the df

survey_df = pd.concat([pd.read_csv(fp).assign(New=os.path.basename(fp).split('.')[0]) for fp in files])

#rename the new column

survey_df.rename(columns={'New':'Hosp_ID'}, inplace=True)
survey_df.head(5)
# Out:
#        measure_set_name                                       measure_name  \
# 0  CMS 30-day Mortality                    Pneumonia 30-Day Mortality Rate
# 1  CMS 30-day Mortality                Heart Failure 30-Day Mortality Rate
# 2  CMS 30-day Mortality                 Heart Attack 30-Day Mortality Rate
# 3   Inpatient Mortality  Risk-adjusted Mortality Rate: Inpatient Bypass...
# 4   Inpatient Mortality  Risk-adjusted Mortality Rate: Heart Attack Dea...
#
#           hospital_name          value  date_start    date_end  \
# 0  Kirby Medical Center          13.8%  07/01/2015  06/30/2018
# 1  Kirby Medical Center            NaN  07/01/2015  06/30/2018
# 2  Kirby Medical Center            NaN  07/01/2015  06/30/2018
# 3  Kirby Medical Center            NaN         NaN         NaN
# 4  Kirby Medical Center  too few cases  01/01/2015  12/31/2015
#
#            Hosp_ID
# 0  hospital_101294
# 1  hospital_101294
# 2  hospital_101294
# 3  hospital_101294
# 4  hospital_101294

# %%
#get number and list of hospital names to use when scraping Glassdoor reviews

numHosp = len(survey_df.hospital_name.unique())
print(numHosp)

names = pd.DataFrame(survey_df.hospital_name.unique())
names.to_csv("HospNamesList.csv")

##a few hospitals have the same exact name, but different ID, hence 181 != 184 files
# Out:
# 181

# %%
#create unique IDs for each hospital to deal with duplicate hospital names
#pivot data to get one row per hospital 

survey_df['Hospital'] = survey_df['Hosp_ID'].str.cat(survey_df['hospital_name'], sep = ': ')
survey_df = survey_df.drop_duplicates(['Hosp_ID', 'measure_name', 'hospital_name'])
survey_df_wide = pd.pivot(survey_df, index = 'Hospital', columns = 'measure_name', values = 'value').reset_index()
survey_df_wide.shape #184, 281

survey_df_wide.head(5)
# Out:
# measure_name                                           Hospital  \
# 0                              hospital_101152: Graham Hospital
# 1                      hospital_101153: Alton Memorial Hospital
# 2             hospital_101154: Amita Health Saint Joseph Med...
# 3             hospital_101155: Loyola Gottlieb Memorial Hosp...
# 4             hospital_101156: Northshore Univ HS Evanston H...
#
# measure_name                 Accidental Puncture and Laceration  \
# 0             Statistically significantly better or performi...
# 1               Not statistically significantly better or worse
# 2               Not statistically significantly better or worse
# 3             Statistically significantly better or performi...
# 4               Not statistically significantly better or worse
#
# measure_name     Accidental Puncture and Laceration, Pediatric   \
# 0             Statistically significantly better or performi...
# 1             Statistically significantly better or performi...
# 2                             Statistically significantly worse
# 3             Statistically significantly better or performi...
# 4             Statistically significantly better or performi...
#
# measure_name Acute Mental Illness Beds\r\n  \
# 0                                        0
# 1                                       20
# 2                                       31
# 3                                       12
# 4                                       21
#
# measure_name Admit decision time to ED departure time for admitted patients  \
# 0                                                    79 minutes
# 1                                                    55 minutes
# 2                                                   130 minutes
# 3                                                   140 minutes
# 4                                                   164 minutes
#
# measure_name Bi-Lateral Cardiac Catheterization   \
# 0                                  too few cases
# 1                                   5.43per 1000
# 2                                  26.32per 1000
# 3                                   4.33per 1000
# 4                                   3.68per 1000
#
# measure_name                                     Birth Trauma  \
# 0                                               too few cases
# 1                                               too few cases
# 2                                               too few cases
# 3                                                         NaN
# 4             Not statistically significantly better or worse
#
# measure_name Blood Transfusion Reaction  Bypass Hours  \
# 0                                    NaN          NaN
# 1                                    NaN          NaN
# 2                                    NaN   2.34 hours
# 3                                    NaN  71.11 hours
# 4                                    NaN          NaN
#
# measure_name Central Line Associated Bloodstream Infections in Pediatric Medical ICU  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
#
# measure_name  ... Total RN Nursing Hours per Patient Day (Critical Care)  \
# 0             ...                                        16.93 hours
# 1             ...                                        15.11 hours
# 2             ...                                        16.73 hours
# 3             ...                                        15.28 hours
# 4             ...                                        16.26 hours
#
# measure_name Total RN Nursing Hours per Patient Day (Medical-Surgical)  \
# 0                                                    4.76 hours
# 1                                                     6.9 hours
# 2                                                    6.81 hours
# 3                                                    7.12 hours
# 4                                                    5.75 hours
#
# measure_name Total RN Nursing Hours per Patient Day (Mother/Baby)  \
# 0                                                   18.01 hours
# 1                                                    8.45 hours
# 2                                                   12.17 hours
# 3                                                       0 hours
# 4                                                    8.43 hours
#
# measure_name Total RN Nursing Hours per Patient Day (NICU)  \
# 0                                                  0 hours
# 1                                                  0 hours
# 2                                                  0 hours
# 3                                                  0 hours
# 4                                              11.84 hours
#
# measure_name Total Vaginal Births After Cesarean  \
# 0                                  108.7per 1000
# 1                                  too few cases
# 2                                  57.97per 1000
# 3                                            NaN
# 4                                 344.58per 1000
#
# measure_name Uncomplicated Vaginal Births After Cesarean  \
# 0                                          too few cases
# 1                                          too few cases
# 2                                          65.93per 1000
# 3                                                    NaN
# 4                                         361.17per 1000
#
# measure_name                                  Unexpected Deaths  \
# 0             Statistically significantly better or performi...
# 1             Statistically significantly better or performi...
# 2               Not statistically significantly better or worse
# 3                             Statistically significantly worse
# 4             Statistically significantly better or performi...
#
# measure_name Volume: CT Scan Head (Inpatient)  \
# 0                                         311
# 1                                       1,649
# 2                                       4,640
# 3                                       1,268
# 4                                       4,479
#
# measure_name Volume: CT Scan Head (Outpatient)  \
# 0                                        1,673
# 1                                        3,689
# 2                                        7,300
# 3                                        3,250
# 4                                        4,942
#
# measure_name      Wound Complications in Abdominal Wall Surgery
# 0             Statistically significantly better or performi...
# 1             Statistically significantly better or performi...
# 2             Statistically significantly better or performi...
# 3             Statistically significantly better or performi...
# 4               Not statistically significantly better or worse
#
# [5 rows x 281 columns]

# %%
#pull out relevant columns that may inform nurse turnover
#there is a lot more information than we need to build a baseline model; more features could be added in later iterations

survey_df_wide_rel = pd.DataFrame(survey_df_wide[['Hospital', 'Doctors Always Communicated Well','Emergency Department Visits, Total',
 'Number of Beds','Nurses Always Communicated Well',
 'Patients Always Received Help As Soon As They Wanted',
 'Patients Would Definitely Recommend This Hospital to Friends and Family',
 'Percent RN Nursing Staff Hours (Critical Care)',
 'Percentage of Nursing Hours Worked by Hospital Employed RNs (Critical Care)',
 'RN Turnover Rate in the Critical Care Unit',
 'RN Turnover Rate in the Medical-Surgical Unit',
 'RN Turnover Rate in the Mother/Baby Unit',
 'Time from ED arrival to diagnostic evaluation by a qualified medical professional','Percent RN Nursing Staff Hours (Critical Care)','Total RN Nursing Hours per Patient Day (Critical Care)',
 'Total RN Nursing Hours per Patient Day (Medical-Surgical)', 'Percentage of Nursing Hours Worked by Hospital Employed RNs (Medical-Surgical)','Heart Attack 30-Day Mortality Rate','Pneumonia 30-Day Mortality Rate', 'Percent RN Nursing Staff Hours (Medical-Surgical)','Median Length of Stay for DRG 638, Diabetes with Complications','Median Length of Stay: Septicemia with Multiple Complications']])

# %%
#initially we use 22 features of the 281 in the data set

survey_df_wide_rel.shape #184, 22
survey_df_wide_rel.head()
# Out:
# measure_name                                           Hospital  \
# 0                              hospital_101152: Graham Hospital
# 1                      hospital_101153: Alton Memorial Hospital
# 2             hospital_101154: Amita Health Saint Joseph Med...
# 3             hospital_101155: Loyola Gottlieb Memorial Hosp...
# 4             hospital_101156: Northshore Univ HS Evanston H...
#
# measure_name Doctors Always Communicated Well  \
# 0                                         85%
# 1                                         76%
# 2                                         76%
# 3                                         78%
# 4                                         81%
#
# measure_name Emergency Department Visits, Total Number of Beds  \
# 0                               13,205 patients             87
# 1                               35,566 patients            181
# 2                               57,237 patients            498
# 3                               25,358 patients            247
# 4                               35,149 patients            354
#
# measure_name Nurses Always Communicated Well  \
# 0                                        80%
# 1                                        78%
# 2                                        77%
# 3                                        78%
# 4                                        80%
#
# measure_name Patients Always Received Help As Soon As They Wanted  \
# 0                                                           68%
# 1                                                           64%
# 2                                                           63%
# 3                                                           66%
# 4                                                           64%
#
# measure_name Patients Would Definitely Recommend This Hospital to Friends and Family  \
# 0                                                           60%
# 1                                                           71%
# 2                                                           63%
# 3                                                           63%
# 4                                                           77%
#
# measure_name Percent RN Nursing Staff Hours (Critical Care)  \
# 0                                                    93.18%
# 1                                                    90.26%
# 2                                                    90.65%
# 3                                                    95.07%
# 4                                                    83.26%
#
# measure_name Percentage of Nursing Hours Worked by Hospital Employed RNs (Critical Care)  \
# 0                                                        89.31%
# 1                                                         89.5%
# 2                                                        93.52%
# 3                                                        95.01%
# 4                                                        83.84%
#
# measure_name RN Turnover Rate in the Critical Care Unit  ...  \
# 0                                                   0 %  ...
# 1                                                7.41 %  ...
# 2                                               17.76 %  ...
# 3                                                3.33 %  ...
# 4                                               13.85 %  ...
#
# measure_name Time from ED arrival to diagnostic evaluation by a qualified medical professional  \
# 0                                                     9 minutes
# 1                                                    16 minutes
# 2                                                    40 minutes
# 3                                                    29 minutes
# 4                                                    37 minutes
#
# measure_name Percent RN Nursing Staff Hours (Critical Care)  \
# 0                                                    93.18%
# 1                                                    90.26%
# 2                                                    90.65%
# 3                                                    95.07%
# 4                                                    83.26%
#
# measure_name Total RN Nursing Hours per Patient Day (Critical Care)  \
# 0                                                   16.93 hours
# 1                                                   15.11 hours
# 2                                                   16.73 hours
# 3                                                   15.28 hours
# 4                                                   16.26 hours
#
# measure_name Total RN Nursing Hours per Patient Day (Medical-Surgical)  \
# 0                                                    4.76 hours
# 1                                                     6.9 hours
# 2                                                    6.81 hours
# 3                                                    7.12 hours
# 4                                                    5.75 hours
#
# measure_name Percentage of Nursing Hours Worked by Hospital Employed RNs (Medical-Surgical)  \
# 0                                                        56.55%
# 1                                                        77.08%
# 2                                                        71.54%
# 3                                                        77.65%
# 4                                                        59.36%
#
# measure_name Heart Attack 30-Day Mortality Rate  \
# 0                                           NaN
# 1                                         12.6%
# 2                                         11.9%
# 3                                         12.4%
# 4                                          9.4%
#
# measure_name Pneumonia 30-Day Mortality Rate  \
# 0                                        18%
# 1                                      17.2%
# 2                                      16.6%
# 3                                      15.7%
# 4                                      12.8%
#
# measure_name Percent RN Nursing Staff Hours (Medical-Surgical)  \
# 0                                                      63.88 %
# 1                                                      92.03 %
# 2                                                      66.85 %
# 3                                                      79.32 %
# 4                                                      60.44 %
#
# measure_name Median Length of Stay for DRG 638, Diabetes with Complications  \
# 0                                                        2 days
# 1                                                        3 days
# 2                                                        3 days
# 3                                                      2.5 days
# 4                                                        3 days
#
# measure_name Median Length of Stay: Septicemia with Multiple Complications
# 0                                                        5 days
# 1                                                        4 days
# 2                                                        5 days
# 3                                                        5 days
# 4                                                        5 days
#
# [5 rows x 22 columns]

# %% [markdown]
# There are many extranneous characters in the dataframe that will cause problems when working with the dataframe, thus we need to strip them out (i.e., %, strings, commas).

# %%
#clean % symbols and unnecessary words from dataframe
#units should not be inside the dataframe with the data!

survey_df_wide_rel = survey_df_wide_rel.replace(regex=r'\%', value='')
survey_df_wide_rel = survey_df_wide_rel.replace(regex=r'minutes', value='')
survey_df_wide_rel = survey_df_wide_rel.replace(regex=r'hours', value='')
survey_df_wide_rel = survey_df_wide_rel.replace(regex=r'patients', value='')
survey_df_wide_rel = survey_df_wide_rel.replace(regex=r'\,', value='')
survey_df_wide_rel = survey_df_wide_rel.replace(regex=r'days', value='')
survey_df_wide_rel = survey_df_wide_rel.replace(regex=r'too few cases', value='nan')
survey_df_wide_rel.head()
# Out:
# measure_name                                           Hospital  \
# 0                              hospital_101152: Graham Hospital
# 1                      hospital_101153: Alton Memorial Hospital
# 2             hospital_101154: Amita Health Saint Joseph Med...
# 3             hospital_101155: Loyola Gottlieb Memorial Hosp...
# 4             hospital_101156: Northshore Univ HS Evanston H...
#
# measure_name Doctors Always Communicated Well  \
# 0                                          85
# 1                                          76
# 2                                          76
# 3                                          78
# 4                                          81
#
# measure_name Emergency Department Visits, Total Number of Beds  \
# 0                                        13205              87
# 1                                        35566             181
# 2                                        57237             498
# 3                                        25358             247
# 4                                        35149             354
#
# measure_name Nurses Always Communicated Well  \
# 0                                         80
# 1                                         78
# 2                                         77
# 3                                         78
# 4                                         80
#
# measure_name Patients Always Received Help As Soon As They Wanted  \
# 0                                                            68
# 1                                                            64
# 2                                                            63
# 3                                                            66
# 4                                                            64
#
# measure_name Patients Would Definitely Recommend This Hospital to Friends and Family  \
# 0                                                            60
# 1                                                            71
# 2                                                            63
# 3                                                            63
# 4                                                            77
#
# measure_name Percent RN Nursing Staff Hours (Critical Care)  \
# 0                                                     93.18
# 1                                                     90.26
# 2                                                     90.65
# 3                                                     95.07
# 4                                                     83.26
#
# measure_name Percentage of Nursing Hours Worked by Hospital Employed RNs (Critical Care)  \
# 0                                                         89.31
# 1                                                          89.5
# 2                                                         93.52
# 3                                                         95.01
# 4                                                         83.84
#
# measure_name RN Turnover Rate in the Critical Care Unit  ...  \
# 0                                                    0   ...
# 1                                                 7.41   ...
# 2                                                17.76   ...
# 3                                                 3.33   ...
# 4                                                13.85   ...
#
# measure_name Time from ED arrival to diagnostic evaluation by a qualified medical professional  \
# 0                                                            9
# 1                                                           16
# 2                                                           40
# 3                                                           29
# 4                                                           37
#
# measure_name Percent RN Nursing Staff Hours (Critical Care)  \
# 0                                                     93.18
# 1                                                     90.26
# 2                                                     90.65
# 3                                                     95.07
# 4                                                     83.26
#
# measure_name Total RN Nursing Hours per Patient Day (Critical Care)  \
# 0                                                        16.93
# 1                                                        15.11
# 2                                                        16.73
# 3                                                        15.28
# 4                                                        16.26
#
# measure_name Total RN Nursing Hours per Patient Day (Medical-Surgical)  \
# 0                                                         4.76
# 1                                                          6.9
# 2                                                         6.81
# 3                                                         7.12
# 4                                                         5.75
#
# measure_name Percentage of Nursing Hours Worked by Hospital Employed RNs (Medical-Surgical)  \
# 0                                                         56.55
# 1                                                         77.08
# 2                                                         71.54
# 3                                                         77.65
# 4                                                         59.36
#
# measure_name Heart Attack 30-Day Mortality Rate  \
# 0                                           NaN
# 1                                          12.6
# 2                                          11.9
# 3                                          12.4
# 4                                           9.4
#
# measure_name Pneumonia 30-Day Mortality Rate  \
# 0                                         18
# 1                                       17.2
# 2                                       16.6
# 3                                       15.7
# 4                                       12.8
#
# measure_name Percent RN Nursing Staff Hours (Medical-Surgical)  \
# 0                                                       63.88
# 1                                                       92.03
# 2                                                       66.85
# 3                                                       79.32
# 4                                                       60.44
#
# measure_name Median Length of Stay for DRG 638, Diabetes with Complications  \
# 0                                                            2
# 1                                                            3
# 2                                                            3
# 3                                                          2.5
# 4                                                            3
#
# measure_name Median Length of Stay: Septicemia with Multiple Complications
# 0                                                            5
# 1                                                            4
# 2                                                            5
# 3                                                            5
# 4                                                            5
#
# [5 rows x 22 columns]

# %% [markdown]
# Now we investigate the missing values to determine what to do about them.

# %%
#count the number of missing values to inform decision on how to deal with NaN

cols = survey_df_wide_rel.columns
survey_df_wide_rel.isna().sum()
#print(cols)
# Out:
# measure_name
# Hospital                                                                              0
# Doctors Always Communicated Well                                                      7
# Emergency Department Visits, Total                                                    7
# Number of Beds                                                                        0
# Nurses Always Communicated Well                                                       7
# Patients Always Received Help As Soon As They Wanted                                  7
# Patients Would Definitely Recommend This Hospital to Friends and Family               7
# Percent RN Nursing Staff Hours (Critical Care)                                        4
# Percentage of Nursing Hours Worked by Hospital Employed RNs (Critical Care)           8
# RN Turnover Rate in the Critical Care Unit                                            9
# RN Turnover Rate in the Medical-Surgical Unit                                         9
# RN Turnover Rate in the Mother/Baby Unit                                              9
# Time from ED arrival to diagnostic evaluation by a qualified medical professional    30
# Percent RN Nursing Staff Hours (Critical Care)                                        4
# Total RN Nursing Hours per Patient Day (Critical Care)                                8
# Total RN Nursing Hours per Patient Day (Medical-Surgical)                             8
# Percentage of Nursing Hours Worked by Hospital Employed RNs (Medical-Surgical)        8
# Heart Attack 30-Day Mortality Rate                                                   80
# Pneumonia 30-Day Mortality Rate                                                      10
# Percent RN Nursing Staff Hours (Medical-Surgical)                                     4
# Median Length of Stay for DRG 638, Diabetes with Complications                       12
# Median Length of Stay: Septicemia with Multiple Complications                         8
# dtype: int64

# %%
# change all the numeric data types to float

survey_df_wide_rel_flt = survey_df_wide_rel.iloc[:, 1:22].astype('float64')
survey_df_wide_rel_flt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 21 columns):
# Doctors Always Communicated Well                                                     177 non-null float64
# Emergency Department Visits, Total                                                   177 non-null float64
# Number of Beds                                                                       184 non-null float64
# Nurses Always Communicated Well                                                      177 non-null float64
# Patients Always Received Help As Soon As They Wanted                                 177 non-null float64
# Patients Would Definitely Recommend This Hospital to Friends and Family              177 non-null float64
# Percent RN Nursing Staff Hours (Critical Care)                                       180 non-null float64
# Percentage of Nursing Hours Worked by Hospital Employed RNs (Critical Care)          176 non-null float64
# RN Turnover Rate in the Critical Care Unit                                           175 non-null float64
# RN Turnover Rate in the Medical-Surgical Unit                                        175 non-null float64
# RN Turnover Rate in the Mother/Baby Unit                                             175 non-null float64
# Time from ED arrival to diagnostic evaluation by a qualified medical professional    154 non-null float64
# Percent RN Nursing Staff Hours (Critical Care)                                       180 non-null float64
# Total RN Nursing Hours per Patient Day (Critical Care)                               176 non-null float64
# Total RN Nursing Hours per Patient Day (Medical-Surgical)                            176 non-null float64
# Percentage of Nursing Hours Worked by Hospital Employed RNs (Medical-Surgical)       176 non-null float64
# Heart Attack 30-Day Mortality Rate                                                   104 non-null float64
# Pneumonia 30-Day Mortality Rate                                                      174 non-null float64
# Percent RN Nursing Staff Hours (Medical-Surgical)                                    180 non-null float64
# Median Length of Stay for DRG 638, Diabetes with Complications                       172 non-null float64
# Median Length of Stay: Septicemia with Multiple Complications                        157 non-null float64
# dtypes: float64(21)
# memory usage: 30.3 KB

# %%
#convert object type to category

survey_df_wide_rel_cat = pd.DataFrame(survey_df_wide_rel.iloc[:, 0].astype('category'))

survey_df_wide_rel_cat.head()
survey_data = survey_df_wide_rel_cat.join(survey_df_wide_rel_flt)
survey_data.head(2)

survey_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 22 columns):
# Hospital                                                                             184 non-null category
# Doctors Always Communicated Well                                                     177 non-null float64
# Emergency Department Visits, Total                                                   177 non-null float64
# Number of Beds                                                                       184 non-null float64
# Nurses Always Communicated Well                                                      177 non-null float64
# Patients Always Received Help As Soon As They Wanted                                 177 non-null float64
# Patients Would Definitely Recommend This Hospital to Friends and Family              177 non-null float64
# Percent RN Nursing Staff Hours (Critical Care)                                       180 non-null float64
# Percentage of Nursing Hours Worked by Hospital Employed RNs (Critical Care)          176 non-null float64
# RN Turnover Rate in the Critical Care Unit                                           175 non-null float64
# RN Turnover Rate in the Medical-Surgical Unit                                        175 non-null float64
# RN Turnover Rate in the Mother/Baby Unit                                             175 non-null float64
# Time from ED arrival to diagnostic evaluation by a qualified medical professional    154 non-null float64
# Percent RN Nursing Staff Hours (Critical Care)                                       180 non-null float64
# Total RN Nursing Hours per Patient Day (Critical Care)                               176 non-null float64
# Total RN Nursing Hours per Patient Day (Medical-Surgical)                            176 non-null float64
# Percentage of Nursing Hours Worked by Hospital Employed RNs (Medical-Surgical)       176 non-null float64
# Heart Attack 30-Day Mortality Rate                                                   104 non-null float64
# Pneumonia 30-Day Mortality Rate                                                      174 non-null float64
# Percent RN Nursing Staff Hours (Medical-Surgical)                                    180 non-null float64
# Median Length of Stay for DRG 638, Diabetes with Complications                       172 non-null float64
# Median Length of Stay: Septicemia with Multiple Complications                        157 non-null float64
# dtypes: category(1), float64(21)
# memory usage: 37.1 KB

# %% [markdown]
# Now we need to split the hospital names column to pull out just the text descriptions of the hospital names, which will be useful for downstream analyses such as joining data frames and matching up data sources. The unique IDs have already served their purpose and now each row is a unique hospital.

# %%
hospitalNames = survey_df_wide_rel["Hospital"].str.split(" ", n=1, expand = True)
survey_data['ID']=hospitalNames[0]
survey_data['Name']=hospitalNames[1]
survey_data.head()
# Out:
#                                             Hospital  \
# 0                   hospital_101152: Graham Hospital
# 1           hospital_101153: Alton Memorial Hospital
# 2  hospital_101154: Amita Health Saint Joseph Med...
# 3  hospital_101155: Loyola Gottlieb Memorial Hosp...
# 4  hospital_101156: Northshore Univ HS Evanston H...
#
#    Doctors Always Communicated Well  Emergency Department Visits, Total  \
# 0                              85.0                             13205.0
# 1                              76.0                             35566.0
# 2                              76.0                             57237.0
# 3                              78.0                             25358.0
# 4                              81.0                             35149.0
#
#    Number of Beds  Nurses Always Communicated Well  \
# 0            87.0                             80.0
# 1           181.0                             78.0
# 2           498.0                             77.0
# 3           247.0                             78.0
# 4           354.0                             80.0
#
#    Patients Always Received Help As Soon As They Wanted  \
# 0                                               68.0
# 1                                               64.0
# 2                                               63.0
# 3                                               66.0
# 4                                               64.0
#
#    Patients Would Definitely Recommend This Hospital to Friends and Family  \
# 0                                               60.0
# 1                                               71.0
# 2                                               63.0
# 3                                               63.0
# 4                                               77.0
#
#    Percent RN Nursing Staff Hours (Critical Care)  \
# 0                                           93.18
# 1                                           90.26
# 2                                           90.65
# 3                                           95.07
# 4                                           83.26
#
#    Percentage of Nursing Hours Worked by Hospital Employed RNs (Critical Care)  \
# 0                                              89.31
# 1                                              89.50
# 2                                              93.52
# 3                                              95.01
# 4                                              83.84
#
#    RN Turnover Rate in the Critical Care Unit  ...  \
# 0                                        0.00  ...
# 1                                        7.41  ...
# 2                                       17.76  ...
# 3                                        3.33  ...
# 4                                       13.85  ...
#
#    Total RN Nursing Hours per Patient Day (Critical Care)  \
# 0                                              16.93
# 1                                              15.11
# 2                                              16.73
# 3                                              15.28
# 4                                              16.26
#
#    Total RN Nursing Hours per Patient Day (Medical-Surgical)  \
# 0                                               4.76
# 1                                               6.90
# 2                                               6.81
# 3                                               7.12
# 4                                               5.75
#
#    Percentage of Nursing Hours Worked by Hospital Employed RNs (Medical-Surgical)  \
# 0                                              56.55
# 1                                              77.08
# 2                                              71.54
# 3                                              77.65
# 4                                              59.36
#
#    Heart Attack 30-Day Mortality Rate  Pneumonia 30-Day Mortality Rate  \
# 0                                 NaN                             18.0
# 1                                12.6                             17.2
# 2                                11.9                             16.6
# 3                                12.4                             15.7
# 4                                 9.4                             12.8
#
#    Percent RN Nursing Staff Hours (Medical-Surgical)  \
# 0                                              63.88
# 1                                              92.03
# 2                                              66.85
# 3                                              79.32
# 4                                              60.44
#
#    Median Length of Stay for DRG 638, Diabetes with Complications  \
# 0                                                2.0
# 1                                                3.0
# 2                                                3.0
# 3                                                2.5
# 4                                                3.0
#
#    Median Length of Stay: Septicemia with Multiple Complications  \
# 0                                                5.0
# 1                                                4.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#                  ID                                             Name
# 0  hospital_101152:                                  Graham Hospital
# 1  hospital_101153:                          Alton Memorial Hospital
# 2  hospital_101154:  Amita Health Saint Joseph Medical Center Joliet
# 3  hospital_101155:                Loyola Gottlieb Memorial Hospital
# 4  hospital_101156:             Northshore Univ HS Evanston Hospital
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Now we need to combine the RN turnover columns, taking the maximum turnover rate per hospital, and join the survey data with the employee review data
#
# Some hospitals have all four medical unit types: Critical Care, Medical-Surgical, Mother/Baby, Neonatal. Very few had Neonatal, so we did not consider that in this analysis. Larger hospitals have all four units, so it would create a lot of missing values if we kept all four unit types in the analysis. Thus, we create a new dataframe and then take the maximum value in any unit within each hospital, to use as our training labels.

# %%
turnover = survey_data[["RN Turnover Rate in the Critical Care Unit", 
          "RN Turnover Rate in the Medical-Surgical Unit",
          "RN Turnover Rate in the Mother/Baby Unit",
           "Name"]]
turnover.head()
# Out:
#    RN Turnover Rate in the Critical Care Unit  \
# 0                                        0.00
# 1                                        7.41
# 2                                       17.76
# 3                                        3.33
# 4                                       13.85
#
#    RN Turnover Rate in the Medical-Surgical Unit  \
# 0                                           0.00
# 1                                           7.69
# 2                                          16.28
# 3                                           9.84
# 4                                          22.45
#
#    RN Turnover Rate in the Mother/Baby Unit  \
# 0                                      0.00
# 1                                     15.38
# 2                                      7.14
# 3                                      0.00
# 4                                      5.77
#
#                                               Name
# 0                                  Graham Hospital
# 1                          Alton Memorial Hospital
# 2  Amita Health Saint Joseph Medical Center Joliet
# 3                Loyola Gottlieb Memorial Hospital
# 4             Northshore Univ HS Evanston Hospital

# %%
turn2 = pd.DataFrame(turnover[["RN Turnover Rate in the Critical Care Unit", 
          "RN Turnover Rate in the Medical-Surgical Unit",
          "RN Turnover Rate in the Mother/Baby Unit"]].max(axis=1))


survey_data2=survey_data.join(turn2)#.drop(['Hospital', 'RN Turnover', 'Num_Units'], axis=1)
turn2.head(10)

#export the final dataframe to use in our training notebook

survey_data2.to_csv("SurveyData.csv")
# Out:
#        0
# 0   0.00
# 1  15.38
# 2  17.76
# 3   9.84
# 4  22.45
# 5  36.96
# 6  15.00
# 7  20.00
# 8  40.79
# 9  25.42
